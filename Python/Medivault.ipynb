# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/MediVault_500_Medicine_Dataset.csv")

# %%
df.head()
# Out:
#   Medicine_ID Medicine_Name  Generic_Name  Category  Dosage Manufacturer  \
# 0      MED001    Cetirizine    Cetirizine     Syrup    5 ml   Sun Pharma
# 1      MED002       Calcium       Calcium   Capsule  650 mg      Mankind
# 2      MED003  Pantoprazole  Pantoprazole  Ointment    5 ml      Torrent
# 3      MED004  Pantoprazole  Pantoprazole     Syrup  650 mg      Mankind
# 4      MED005  Azithromycin  Azithromycin    Tablet  500 mg        Lupin
#
#   Batch_Number  Stock_Quantity  Minimum_Stock Expiry_Date Purchase_Date  \
# 0        B2200             414             20  2026-06-28    2025-08-04
# 1        B7855              56             50  2027-10-18    2025-08-09
# 2        B2958             348             20  2026-07-29    2025-10-17
# 3        B1411             165             50  2027-10-07    2025-11-30
# 4        B5912             140             50  2026-07-07    2025-03-30
#
#    Unit_Price      Supplier Storage_Location  Status
# ...

# %%
df.tail()
# Out:
#     Medicine_ID Medicine_Name  Generic_Name   Category  Dosage Manufacturer  \
# 495      MED496   Paracetamol   Paracetamol  Injection   10 ml  Dr. Reddy's
# 496      MED497  Atorvastatin  Atorvastatin  Injection   10 ml        Alkem
# 497      MED498    Amlodipine    Amlodipine   Ointment  500 mg      Mankind
# 498      MED499    Omeprazole    Omeprazole     Tablet  100 IU  Dr. Reddy's
# 499      MED500     Ibuprofen     Ibuprofen     Tablet  250 mg        Cipla
#
#     Batch_Number  Stock_Quantity  Minimum_Stock Expiry_Date Purchase_Date  \
# 495        B1644             151             30  2028-06-07    2025-11-05
# 496        B6334             200             50  2028-04-18    2025-07-01
# 497        B4213             404             30  2026-07-08    2025-07-28
# 498        B5940             123             30  2026-12-27    2025-06-26
# 499        B4838             340             50  2027-05-21    2025-05-30
#
#      Unit_Price      Supplier Storage_Location  Status
# ...

# %%
df.sample(3)
# Out:
#     Medicine_ID Medicine_Name Generic_Name   Category  Dosage Manufacturer  \
# 406      MED407     Ibuprofen    Ibuprofen    Capsule    5 ml       Abbott
# 385      MED386       Insulin      Insulin  Injection   10 ml        Lupin
# 224      MED225    Cetirizine   Cetirizine    Capsule  100 IU        Cipla
#
#     Batch_Number  Stock_Quantity  Minimum_Stock Expiry_Date Purchase_Date  \
# 406        B4537             272             30  2027-04-14    2025-05-02
# 385        B9420              18             20  2027-04-21    2025-05-30
# 224        B8074             213             30  2027-01-24    2025-06-09
#
#      Unit_Price    Supplier Storage_Location  Status
# 406      397.03    LifeCare               C1  Active
# 385      346.30  ABC Pharma               C1  Active
# 224      332.38  MediSupply               B2  Active

# %%
df.shape
df.columns
df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Medicine_ID       500 non-null    object
#  1   Medicine_Name     500 non-null    object
#  2   Generic_Name      500 non-null    object
#  3   Category          500 non-null    object
#  4   Dosage            500 non-null    object
#  5   Manufacturer      500 non-null    object
#  6   Batch_Number      500 non-null    object
#  7   Stock_Quantity    500 non-null    int64
#  8   Minimum_Stock     500 non-null    int64
#  9   Expiry_Date       500 non-null    object
#  10  Purchase_Date     500 non-null    object
#  11  Unit_Price        500 non-null    float64
#  12  Supplier          500 non-null    object
#  13  Storage_Location  500 non-null    object
#  14  Status            500 non-null    object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 58.7+ KB

# %%
df.describe()
# Out:
#        Stock_Quantity  Minimum_Stock  Unit_Price
# count      500.000000     500.000000  500.000000
# mean       253.548000      33.420000  250.085480
# std        143.562921      12.729008  142.916164
# min          1.000000      20.000000    5.620000
# 25%        129.750000      20.000000  126.260000
# 50%        262.500000      30.000000  247.865000
# 75%        373.500000      50.000000  371.127500
# max        500.000000      50.000000  497.450000

# %%
sns.histplot(x='Category',data=df)
plt.show()

# %%
sns.countplot(x='Stock_Quantity',data=df)
plt.show()

# %%
sns.violinplot(x='Category',y='Unit_Price',data=df)
plt.show()

# %%
sns.boxplot(x='Category',y='Unit_Price',data=df)
plt.show()

# %%
sns.barplot(x='Category',y='Unit_Price',data=df)
plt.show()

# %%
sns.kdeplot(x='Stock_Quantity',data=df,hue='Status')
plt.show()

# %%
df.isnull().sum()
# Out:
# Medicine_ID         0
# Medicine_Name       0
# Generic_Name        0
# Category            0
# Dosage              0
# Manufacturer        0
# Batch_Number        0
# Stock_Quantity      0
# Minimum_Stock       0
# Expiry_Date         0
# Purchase_Date       0
# Unit_Price          0
# Supplier            0
# Storage_Location    0
# Status              0
# dtype: int64

# %%
df.dropna()
# Out:
#     Medicine_ID Medicine_Name  Generic_Name   Category  Dosage Manufacturer  \
# 0        MED001    Cetirizine    Cetirizine      Syrup    5 ml   Sun Pharma
# 1        MED002       Calcium       Calcium    Capsule  650 mg      Mankind
# 2        MED003  Pantoprazole  Pantoprazole   Ointment    5 ml      Torrent
# 3        MED004  Pantoprazole  Pantoprazole      Syrup  650 mg      Mankind
# 4        MED005  Azithromycin  Azithromycin     Tablet  500 mg        Lupin
# ..          ...           ...           ...        ...     ...          ...
# 495      MED496   Paracetamol   Paracetamol  Injection   10 ml  Dr. Reddy's
# 496      MED497  Atorvastatin  Atorvastatin  Injection   10 ml        Alkem
# 497      MED498    Amlodipine    Amlodipine   Ointment  500 mg      Mankind
# 498      MED499    Omeprazole    Omeprazole     Tablet  100 IU  Dr. Reddy's
# 499      MED500     Ibuprofen     Ibuprofen     Tablet  250 mg        Cipla
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#     Medicine_ID Medicine_Name  Generic_Name   Category  Dosage Manufacturer  \
# 0        MED001    Cetirizine    Cetirizine      Syrup    5 ml   Sun Pharma
# 1        MED002       Calcium       Calcium    Capsule  650 mg      Mankind
# 2        MED003  Pantoprazole  Pantoprazole   Ointment    5 ml      Torrent
# 3        MED004  Pantoprazole  Pantoprazole      Syrup  650 mg      Mankind
# 4        MED005  Azithromycin  Azithromycin     Tablet  500 mg        Lupin
# ..          ...           ...           ...        ...     ...          ...
# 495      MED496   Paracetamol   Paracetamol  Injection   10 ml  Dr. Reddy's
# 496      MED497  Atorvastatin  Atorvastatin  Injection   10 ml        Alkem
# 497      MED498    Amlodipine    Amlodipine   Ointment  500 mg      Mankind
# 498      MED499    Omeprazole    Omeprazole     Tablet  100 IU  Dr. Reddy's
# 499      MED500     Ibuprofen     Ibuprofen     Tablet  250 mg        Cipla
#
# ...

# %%
df['Category'].unique()
# Out:
# array(['Syrup', 'Capsule', 'Ointment', 'Tablet', 'Injection'],
#       dtype=object)

# %%
df['Category'].nunique()
# Out:
# 5

# %%
df['Category'].value_counts()
# Out:
# Category
# Injection    115
# Capsule      110
# Tablet       102
# Ointment      94
# Syrup         79
# Name: count, dtype: int64

# %%
df['Category'] = df['Category'].fillna(df['Category'].mode()[0])

# %%
df['Unit_Price'].skew()
# Out:
# np.float64(-0.022568679205309486)

# %%
Q1=df['Minimum_Stock'].quantile(0.25)
Q3=df['Minimum_Stock'].quantile(0.75)
IQR=Q3-Q1
lower = Q1-1.5*IQR
upper = Q3+1.5*IQR
outlier = df[(df['Minimum_Stock']<lower)|(df['Minimum_Stock']>upper)]

# %%
outlier
# Out:
# Empty DataFrame
# Columns: [Medicine_ID, Medicine_Name, Generic_Name, Category, Dosage, Manufacturer, Batch_Number, Stock_Quantity, Minimum_Stock, Expiry_Date, Purchase_Date, Unit_Price, Supplier, Storage_Location, Status]
# Index: []

# %%
outlier.shape[0]
# Out:
# 0

# %%
corr = df.corr(numeric_only=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
plt.show()

# %%
sns.scatterplot(x='Category',y='Unit_Price',data=df)
plt.show()
