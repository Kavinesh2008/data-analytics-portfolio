# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/student_performance.csv");

# %%
df.head()
df.tail()
df.sample(4)
df.shape
df.dtypes
df.columns
# Out:
# Index(['StudyHours', 'Attendance', 'Resources', 'Extracurricular',
#        'Motivation', 'Internet', 'Gender', 'Age', 'LearningStyle',
#        'OnlineCourses', 'Discussions', 'AssignmentCompletion', 'ExamScore',
#        'EduTech', 'StressLevel', 'FinalGrade'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14003 entries, 0 to 14002
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   StudyHours            14003 non-null  int64
#  1   Attendance            14003 non-null  int64
#  2   Resources             14003 non-null  int64
#  3   Extracurricular       14003 non-null  int64
#  4   Motivation            14003 non-null  int64
#  5   Internet              14003 non-null  int64
#  6   Gender                14003 non-null  int64
#  7   Age                   14003 non-null  int64
#  8   LearningStyle         14003 non-null  int64
#  9   OnlineCourses         14003 non-null  int64
#  10  Discussions           14003 non-null  int64
#  11  AssignmentCompletion  14003 non-null  int64
#  12  ExamScore             14003 non-null  int64
#  13  EduTech               14003 non-null  int64
#  14  StressLevel           14003 non-null  int64
# ...

# %%
df.describe()
# Out:
#          StudyHours    Attendance     Resources  Extracurricular  \
# count  14003.000000  14003.000000  14003.000000     14003.000000
# mean      19.987431     80.194316      1.104406         0.594158
# std        5.890637     11.472181      0.697362         0.491072
# min        5.000000     60.000000      0.000000         0.000000
# 25%       16.000000     70.000000      1.000000         0.000000
# 50%       20.000000     80.000000      1.000000         1.000000
# 75%       24.000000     90.000000      2.000000         1.000000
# max       44.000000    100.000000      2.000000         1.000000
#
#          Motivation      Internet        Gender           Age  LearningStyle  \
# count  14003.000000  14003.000000  14003.000000  14003.000000   14003.000000
# mean       0.905806      0.925516      0.551953     23.532172       1.515461
# std        0.695896      0.262566      0.497311      3.514293       1.112941
# ...

# %%
df.isnull().sum()
# Out:
# StudyHours              0
# Attendance              0
# Resources               0
# Extracurricular         0
# Motivation              0
# Internet                0
# Gender                  0
# Age                     0
# LearningStyle           0
# OnlineCourses           0
# Discussions             0
# AssignmentCompletion    0
# ExamScore               0
# EduTech                 0
# StressLevel             0
# FinalGrade              0
# dtype: int64

# %%
df.dropna()
# Out:
#        StudyHours  Attendance  Resources  Extracurricular  Motivation  \
# 0              19          64          1                0           0
# 1              19          64          1                0           0
# 2              19          64          1                0           0
# 3              19          64          1                1           0
# 4              19          64          1                1           0
# ...           ...         ...        ...              ...         ...
# 13998          30          62          0                1           1
# 13999          30          62          0                1           1
# 14000          22          90          2                0           1
# 14001          22          90          2                0           1
# 14002          10          86          2                1           2
#
#        Internet  Gender  Age  LearningStyle  OnlineCourses  Discussions  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(1534)

# %%
df.columns
# Out:
# Index(['StudyHours', 'Attendance', 'Resources', 'Extracurricular',
#        'Motivation', 'Internet', 'Gender', 'Age', 'LearningStyle',
#        'OnlineCourses', 'Discussions', 'AssignmentCompletion', 'ExamScore',
#        'EduTech', 'StressLevel', 'FinalGrade'],
#       dtype='object')

# %%
df['Age'].unique()
# Out:
# array([19, 23, 28, 29, 27, 25, 20, 26, 21, 18, 24, 22])

# %%
df['Age'].nunique()
# Out:
# 12

# %%
df['Age'].value_counts()
# Out:
# Age
# 19    1290
# 29    1267
# 27    1263
# 18    1187
# 25    1186
# 23    1179
# 26    1161
# 21    1152
# 28    1151
# 20    1127
# 22    1036
# 24    1004
# Name: count, dtype: int64

# %%
df.skew()
# Out:
# StudyHours              0.098077
# Attendance             -0.011975
# Resources              -0.144644
# Extracurricular        -0.383536
# Motivation              0.129042
# Internet               -3.241670
# Gender                 -0.208966
# Age                    -0.015784
# LearningStyle          -0.012299
# OnlineCourses           0.021843
# Discussions            -0.433352
# AssignmentCompletion    0.049256
# ExamScore              -0.017951
# EduTech                -0.920683
# StressLevel            -0.592578
# FinalGrade              0.040771
# dtype: float64

# %%
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3-Q1
lower = Q1-IQR*1.5
upper = Q3+IQR*1.5
outliers = df[(df['Age']<lower)|(df['Age']>upper)]
outliers
# Out:
# Empty DataFrame
# Columns: [StudyHours, Attendance, Resources, Extracurricular, Motivation, Internet, Gender, Age, LearningStyle, OnlineCourses, Discussions, AssignmentCompletion, ExamScore, EduTech, StressLevel, FinalGrade]
# Index: []

# %%
sns.boxplot(x='Age',data=df)
plt.show()

# %%
corr = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %%
sns.histplot(x='StudyHours',data=df)
plt.show()

# %%
sns.countplot(x='StudyHours',data=df)
plt.show()

# %%
sns.violinplot(x='EduTech',y='FinalGrade',data=df)
plt.show()

# %%
sns.barplot(x='StudyHours',y='FinalGrade',data=df)
plt.show()

# %%
sns.scatterplot(x='StudyHours',y='FinalGrade',data=df)
plt.show()
